# %%
import cv2 as cv
from PIL import Image
from IPython.display import display
import pytesseract

# %%
img = cv.imread("text1.jpg")
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x560>

# %%
! tesseract --list-langs
# Out:
# List of available languages in "/opt/homebrew/share/tessdata/" (3):
# eng
# osd
# rus

# %%
text = pytesseract.image_to_string(img, lang="eng")
print(text)
# Out:
# +
# fly npodeccopa ofHoro KUN, KOTOPbIN A3bIK seepen w3yyuan. Bot u
# Bblyunsica. Ceiuac 6e3 n3biKa Heyib3a. [ponapellb cpazy, HK M3 TeOA
# wanky Cfesator, WIM BOPOTHHK, MIM NIpOcTo KOBpHK AIA HOT.
